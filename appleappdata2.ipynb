# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/madhu/Documents/appleAppData.csv')

# %%
df.head(10)
# Out:
#                              App_Id  \
# 0               com.hkbu.arc.apaper
# 1               com.dmitriev.abooks
# 2                    no.terp.abooks
# 3          fr.antoinettefleur.Book1
# 4  com.imonstersoft.azdictionaryios
# 5                   com.sm.apjkalam
# 6    com.chawlapublication.andhralr
# 7  BestPracticeSystems.IOSAppUpload
# 8                    a2.it.team.leo
# 9                   com.aaaakh.news
#
#                                             App_Name  \
# 0                                     A+ Paper Guide
# 1                                            A-Books
# 2                                            A-books
# 3                                        A-F Book #1
# 4                            A-Z Synonyms Dictionary
# 5  A. P. J. Abdul Kalam Quotes olx Quotation Flip...
# 6                       A.P. Telangana Legal Reports
# 7                             A19BestPracticeSystems
# 8                                       A2 Directory
# ...

# %%
df.tail(5)
# Out:
#                                 App_Id                        App_Name  \
# 1048570                  com.gkgoswami  Gopal Krishna Goswami Maharaja
# 1048571                   com.occ.gsoc           Gopher State One Call
# 1048572  com.qtechnetwork.GoPlus-Store                  GoPlus - Store
# 1048573       com.delta2flat.Gor-Books                       Gor Books
# 1048574         mk.gorivo.cenanagorivo       Gorivo.mk - Cena na nafta
#
#                                               AppStore_Url Primary_Genre  \
# 1048570  https://apps.apple.com/us/app/gopal-krishna-go...     Reference
# 1048571  https://apps.apple.com/us/app/gopher-state-one...     Utilities
# 1048572  https://apps.apple.com/us/app/goplus-store/id1...     Reference
# 1048573  https://apps.apple.com/us/app/gor-books/id6502...     Reference
# 1048574  https://apps.apple.com/us/app/gorivo-mk-cena-n...     Utilities
#
#         Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# ...

# %%
df.shape
# Out:
# (1048575, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1048575 non-null  object
#  1   App_Name                 1048574 non-null  object
#  2   AppStore_Url             1048575 non-null  object
#  3   Primary_Genre            1048575 non-null  object
#  4   Content_Rating           1048575 non-null  object
#  5   Size_Bytes               1048351 non-null  float64
#  6   Required_IOS_Version     1048575 non-null  object
#  7   Released                 1048572 non-null  object
#  8   Updated                  1048575 non-null  object
#  9   Version                  1048575 non-null  object
#  10  Price                    1048091 non-null  float64
#  11  Currency                 1048575 non-null  object
#  12  Free                     1048575 non-null  bool
# ...

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.048351e+06  1.048091e+06  1.048575e+06         1.048575e+06
# mean   7.930055e+07  5.135435e-01  1.083696e+09         1.853936e+00
# std    2.488084e+08  6.820463e+00  4.110013e+08         2.165553e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.138931e+07  0.000000e+00  7.148047e+08         0.000000e+00
# 50%    4.487168e+07  0.000000e+00  1.164224e+09         0.000000e+00
# 75%    8.706970e+07  0.000000e+00  1.468235e+09         4.404645e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.048575e+06           1.048575e+06             1.048575e+06
# mean   8.911496e+02           1.853936e+00             8.911496e+02
# std    5.299912e+04           2.165553e+00             5.299912e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %%
for col in df.columns:
    df[col].isna().sum()
    print(col, '=>',df[col].isna().sum())
# Out:
# App_Id => 0
# App_Name => 1
# AppStore_Url => 0
# Primary_Genre => 0
# Content_Rating => 0
# Size_Bytes => 224
# Required_IOS_Version => 0
# Released => 3
# Updated => 0
# Version => 0
# Price => 484
# Currency => 0
# Free => 0
# DeveloperId => 0
# Developer => 0
# Developer_Url => 967
# Developer_Website => 543001
# Average_User_Rating => 0
# Reviews => 0
# Current_Version_Score => 0
# Current_Version_Reviews => 0

# %%
for col in df.columns:
    print(col,'=>',df[col].isna().sum())
    print('   percentage =>   ',((df[col].isna().sum())/len(df))*100)
# Out:
# App_Id => 0
#    percentage =>    0.0
# App_Name => 1
#    percentage =>    9.536752259018191e-05
# AppStore_Url => 0
#    percentage =>    0.0
# Primary_Genre => 0
#    percentage =>    0.0
# Content_Rating => 0
#    percentage =>    0.0
# Size_Bytes => 224
#    percentage =>    0.02136232506020075
# Required_IOS_Version => 0
#    percentage =>    0.0
# Released => 3
#    percentage =>    0.00028610256777054574
# Updated => 0
#    percentage =>    0.0
# Version => 0
#    percentage =>    0.0
# Price => 484
#    percentage =>    0.046157880933648046
# Currency => 0
#    percentage =>    0.0
# Free => 0
#    percentage =>    0.0
# DeveloperId => 0
#    percentage =>    0.0
# Developer => 0
#    percentage =>    0.0
# Developer_Url => 967
#    percentage =>    0.09222039434470591
# Developer_Website => 543001
#    percentage =>    51.784660133991366
# Average_User_Rating => 0
#    percentage =>    0.0
# Reviews => 0
#    percentage =>    0.0
# Current_Version_Score => 0
# ...

# %%
df.drop('Developer_Website', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1048575 non-null  object
#  1   App_Name                 1048574 non-null  object
#  2   AppStore_Url             1048575 non-null  object
#  3   Primary_Genre            1048575 non-null  object
#  4   Content_Rating           1048575 non-null  object
#  5   Size_Bytes               1048351 non-null  float64
#  6   Required_IOS_Version     1048575 non-null  object
#  7   Released                 1048572 non-null  object
#  8   Updated                  1048575 non-null  object
#  9   Version                  1048575 non-null  object
#  10  Price                    1048091 non-null  float64
#  11  Currency                 1048575 non-null  object
#  12  Free                     1048575 non-null  bool
# ...

# %%
df.drop('App_Id', axis=1, inplace=True)
df.drop('AppStore_Url', axis=1, inplace=True)
df.drop('Required_IOS_Version', axis=1, inplace=True)
df.drop('Released', axis=1, inplace=True)
df.drop('Updated', axis=1, inplace=True)
df.drop('Version', axis=1, inplace=True)
df.drop('DeveloperId', axis=1, inplace=True)
df.drop('Developer_Url', axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Name                 1048574 non-null  object
#  1   Primary_Genre            1048575 non-null  object
#  2   Content_Rating           1048575 non-null  object
#  3   Size_Bytes               1048351 non-null  float64
#  4   Price                    1048091 non-null  float64
#  5   Currency                 1048575 non-null  object
#  6   Free                     1048575 non-null  bool
#  7   Developer                1048575 non-null  object
#  8   Average_User_Rating      1048575 non-null  float64
#  9   Reviews                  1048575 non-null  int64
#  10  Current_Version_Score    1048575 non-null  float64
#  11  Current_Version_Reviews  1048575 non-null  int64
# dtypes: bool(1), float64(4), int64(2), object(5)
# memory usage: 89.0+ MB

# %%
df.describe().Price
# Out:
# count    1.048091e+06
# mean     5.135435e-01
# std      6.820463e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.999900e+02
# Name: Price, dtype: float64

# %%
df.Price.mean()
# Out:
# 0.513543480479649

# %%
for i in df.Price.unique():
    print(i)
# Out:
# 0.0
# 2.99
# 1.99
# 0.99
# 4.99
# 9.99
# 5.99
# 6.99
# 16.99
# 19.99
# 39.99
# 59.99
# 8.99
# 7.99
# 18.99
# 3.99
# 24.99
# 14.99
# 28.99
# 21.99
# 13.99
# 10.99
# 11.99
# 129.99
# 22.99
# 139.99
# 25.99
# 12.99
# 49.99
# 23.99
# 119.99
# 79.99
# 17.99
# 499.99
# 249.99
# 199.99
# 229.99
# 34.99
# 20.99
# 99.99
# 33.99
# 54.99
# 45.99
# 44.99
# 29.99
# 69.99
# 27.99
# 84.99
# 64.99
# 15.99
# 26.99
# 35.99
# 40.99
# 174.99
# 149.99
# 94.99
# 74.99
# 349.99
# 48.99
# 109.99
# 38.99
# 31.99
# 36.99
# 89.99
# 169.99
# 124.99
# nan
# 399.99
# 219.99
# 43.99
# 699.99
# 42.99
# 37.99
# 299.99
# 449.99
# 159.99
# 41.99
# 32.99
# 30.99
# 799.99
# 999.99
# 47.99
# 179.99
# 209.99
# 239.99
# 599.99
# 46.99
# 899.99

# %%
price_hist = df['Price']
price_hist.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.sort_values('Price', ascending=False).Price
# Out:
# 482113     999.99
# 707360     999.99
# 444122     999.99
# 168219     999.99
# 935957     999.99
#             ...
# 1010323       NaN
# 1021193       NaN
# 1025478       NaN
# 1034124       NaN
# 1042533       NaN
# Name: Price, Length: 1048575, dtype: float64

# %%
expensiveapps=df[df['Price']==999.99][['App_Name','Primary_Genre','Price','Currency','Average_User_Rating','Content_Rating','Reviews']]
expensiveapps
# Out:
#                                App_Name     Primary_Genre   Price Currency  \
# 87620                     MagnetVision™           Medical  999.99      USD
# 168219    Entertastic white label admin          Business  999.99      USD
# 444122                         RP.MEDIA             Music  999.99      USD
# 482113              ASPL POS (Odoo V13)          Business  999.99      USD
# 482114              ASPL POS (Odoo V14)          Business  999.99      USD
# 707359                     VERT Stealth            Sports  999.99      USD
# 707360                 VERT Team System  Health & Fitness  999.99      USD
# 935957                       CyberTuner             Music  999.99      USD
# 973050   Plane Factor - Private Jet Ops        Navigation  999.99      USD
# 1020170               Shot Tracer Event            Sports  999.99      USD
# 1022813                      YCS Sketch         Utilities  999.99      USD
#
#          Average_User_Rating Content_Rating  Reviews
# ...

# %%
df.sort_values('Price', ascending=False).Price
# Out:
# 482113     999.99
# 707360     999.99
# 444122     999.99
# 168219     999.99
# 935957     999.99
#             ...
# 1010323       NaN
# 1021193       NaN
# 1025478       NaN
# 1034124       NaN
# 1042533       NaN
# Name: Price, Length: 1048575, dtype: float64

# %%
Sumofprice= df.groupby(['Price'])[['App_Name']].count().reset_index().sort_values('Price',ascending=False)
Sumofprice.columns = ['Price','Number']
top_Prices = Sumofprice.head(20)

top_Prices
# Out:
#      Price  Number
# 86  999.99      11
# 85  899.99       1
# 84  799.99       3
# 83  699.99      11
# 82  599.99       3
# 81  499.99       7
# 80  449.99       5
# 79  399.99      17
# 78  349.99      19
# 77  299.99      37
# 76  249.99      20
# 75  239.99       3
# 74  229.99       6
# 73  219.99       8
# 72  209.99       5
# 71  199.99      56
# 70  179.99      10
# 69  174.99       7
# 68  169.99      10
# 67  159.99      13

# %%
top_Prices['Price'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
top_Prices['Number'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.barplot(y = 'Price',x = 'Number', data=Sumofprice)
plt.xticks(rotation=90)
Sumofprice
# Out:
#      Price  Number
# 86  999.99      11
# 85  899.99       1
# 84  799.99       3
# 83  699.99      11
# 82  599.99       3
# ..     ...     ...
# 4     3.99    5877
# 3     2.99   11595
# 2     1.99   16568
# 1     0.99   26222
# 0     0.00  962420
#
# [87 rows x 2 columns]

# %%
for i in df.Primary_Genre.unique():
    print(i)
# Out:
# Education
# Book
# Reference
# News
# Lifestyle
# Health & Fitness
# Games
# Medical
# Food & Drink
# Sports
# Shopping
# Entertainment
# Utilities
# Stickers
# Productivity
# Music
# Photo & Video
# Travel
# Business
# Social Networking
# Magazines & Newspapers
# Navigation
# Finance
# Weather
# Graphics & Design
# Developer Tools

# %%
for i in df.Content_Rating.unique():
    print(i)
# Out:
# 4+
# 17+
# 9+
# 12+
# Not yet rated

# %%
User_rating= df['Average_User_Rating']
User_rating.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
app_data_cate_bar = df.groupby(['Primary_Genre'])[['App_Name']].count().reset_index().sort_values('App_Name',ascending=False)
app_data_cate_bar.columns = ['Primary_Genre','Number']
top_categories = app_data_cate_bar.head(10)

sns.barplot(y = 'Primary_Genre',x = 'Number', data=top_categories)
top_categories
# Out:
#        Primary_Genre  Number
# 7              Games  193615
# 1           Business  127523
# 3          Education  118724
# 10         Lifestyle   82504
# 6       Food & Drink   72773
# 9   Health & Fitness   60481
# 4      Entertainment   52978
# 5            Finance   44768
# 24         Utilities   36143
# 17      Productivity   34629

# %%
app_data_cate_bar = df.groupby(['Primary_Genre'])[['App_Name']].count().reset_index().sort_values('App_Name',ascending=False)
app_data_cate_bar.columns = ['Primary_Genre','Number']
top_categories = app_data_cate_bar.tail(10)

sns.barplot(y = 'Primary_Genre',x = 'Number', data=top_categories)
top_categories
# Out:
#              Primary_Genre  Number
# 21                  Sports   16435
# 20       Social Networking   12774
# 14              Navigation   12361
# 18               Reference   11466
# 0                     Book   11307
# 22                Stickers    5726
# 8        Graphics & Design    2397
# 2          Developer Tools    1697
# 25                 Weather    1373
# 11  Magazines & Newspapers    1228

# %%
plt.figure(figsize=(10, 7))
ax = sns.countplot(y=df.Primary_Genre)
ax.set(xlabel='Number of apps', ylabel='Category')
plt.show()

# %%
sns.countplot(df[df['Price'] != 0][df['Price'] < 10]['Price']).set_title('Paid Price Distribution')
# Out:
# C:\Users\madhu\AppData\Local\Temp/ipykernel_14264/538164884.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.countplot(df[df['Price'] != 0][df['Price'] < 10]['Price']).set_title('Paid Price Distribution')
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Paid Price Distribution')

# %%
price = df.loc[:, ['App_Name', 'Price', 'Primary_Genre']].head(20)
price
# Out:
#                                              App_Name  Price     Primary_Genre
# 0                                      A+ Paper Guide   0.00         Education
# 1                                             A-Books   0.00              Book
# 2                                             A-books   0.00              Book
# 3                                         A-F Book #1   2.99              Book
# 4                             A-Z Synonyms Dictionary   0.00         Reference
# 5   A. P. J. Abdul Kalam Quotes olx Quotation Flip...   0.00              Book
# 6                        A.P. Telangana Legal Reports   0.00              Book
# 7                              A19BestPracticeSystems   0.00              Book
# 8                                        A2 Directory   0.00              Book
# 9                                             A4 News   0.00              News
# 10        AA Audio Companion for Alcoholics Anonymous   0.00              Book
# ...

# %%
price_cleaned = df.loc[:, ['App_Name', 'Price', 'Primary_Genre']]
price_cleaned
# Out:
#                                App_Name  Price Primary_Genre
# 0                        A+ Paper Guide   0.00     Education
# 1                               A-Books   0.00          Book
# 2                               A-books   0.00          Book
# 3                           A-F Book #1   2.99          Book
# 4               A-Z Synonyms Dictionary   0.00     Reference
# ...                                 ...    ...           ...
# 1048570  Gopal Krishna Goswami Maharaja   0.00     Reference
# 1048571           Gopher State One Call   0.00     Utilities
# 1048572                  GoPlus - Store   0.00     Reference
# 1048573                       Gor Books   0.99     Reference
# 1048574       Gorivo.mk - Cena na nafta   0.00     Utilities
#
# [1048575 rows x 3 columns]

# %%
df.sort_values('Price', ascending=True).Price
# Out:
# 0          0.0
# 683707     0.0
# 683708     0.0
# 683709     0.0
# 683710     0.0
#           ...
# 1010323    NaN
# 1021193    NaN
# 1025478    NaN
# 1034124    NaN
# 1042533    NaN
# Name: Price, Length: 1048575, dtype: float64

# %%
df.isnull().sum().Price
# Out:
# 484

# %%
df.Price.max()
# Out:
# 999.99

# %%
df.Price.min()
# Out:
# 0.0

# %%
df.drop('Size_Bytes', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Name                 1048574 non-null  object
#  1   Primary_Genre            1048575 non-null  object
#  2   Content_Rating           1048575 non-null  object
#  3   Price                    1048091 non-null  float64
#  4   Currency                 1048575 non-null  object
#  5   Free                     1048575 non-null  bool
#  6   Developer                1048575 non-null  object
#  7   Average_User_Rating      1048575 non-null  float64
#  8   Reviews                  1048575 non-null  int64
#  9   Current_Version_Score    1048575 non-null  float64
#  10  Current_Version_Reviews  1048575 non-null  int64
# dtypes: bool(1), float64(3), int64(2), object(5)
# memory usage: 81.0+ MB

# %%
df.describe()
# Out:
#               Price  Average_User_Rating       Reviews  Current_Version_Score  \
# count  1.048091e+06         1.048575e+06  1.048575e+06           1.048575e+06
# mean   5.135435e-01         1.853936e+00  8.911496e+02           1.853936e+00
# std    6.820463e+00         2.165553e+00  5.299912e+04           2.165553e+00
# min    0.000000e+00         0.000000e+00  0.000000e+00           0.000000e+00
# 25%    0.000000e+00         0.000000e+00  0.000000e+00           0.000000e+00
# 50%    0.000000e+00         0.000000e+00  0.000000e+00           0.000000e+00
# 75%    0.000000e+00         4.404645e+00  3.000000e+00           4.404645e+00
# max    9.999900e+02         5.000000e+00  2.268533e+07           5.000000e+00
#
#        Current_Version_Reviews
# count             1.048575e+06
# mean              8.911496e+02
# std               5.299912e+04
# min               0.000000e+00
# 25%               0.000000e+00
# 50%               0.000000e+00
# 75%               3.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Name                 1048574 non-null  object
#  1   Primary_Genre            1048575 non-null  object
#  2   Content_Rating           1048575 non-null  object
#  3   Price                    1048091 non-null  float64
#  4   Currency                 1048575 non-null  object
#  5   Free                     1048575 non-null  bool
#  6   Developer                1048575 non-null  object
#  7   Average_User_Rating      1048575 non-null  float64
#  8   Reviews                  1048575 non-null  int64
#  9   Current_Version_Score    1048575 non-null  float64
#  10  Current_Version_Reviews  1048575 non-null  int64
# dtypes: bool(1), float64(3), int64(2), object(5)
# memory usage: 81.0+ MB

# %%
df.Primary_Genre.unique()
# Out:
# array(['Education', 'Book', 'Reference', 'News', 'Lifestyle',
#        'Health & Fitness', 'Games', 'Medical', 'Food & Drink', 'Sports',
#        'Shopping', 'Entertainment', 'Utilities', 'Stickers',
#        'Productivity', 'Music', 'Photo & Video', 'Travel', 'Business',
#        'Social Networking', 'Magazines & Newspapers', 'Navigation',
#        'Finance', 'Weather', 'Graphics & Design', 'Developer Tools'],
#       dtype=object)

# %%
for i in df.Primary_Genre.unique():
    print(i)
# Out:
# Education
# Book
# Reference
# News
# Lifestyle
# Health & Fitness
# Games
# Medical
# Food & Drink
# Sports
# Shopping
# Entertainment
# Utilities
# Stickers
# Productivity
# Music
# Photo & Video
# Travel
# Business
# Social Networking
# Magazines & Newspapers
# Navigation
# Finance
# Weather
# Graphics & Design
# Developer Tools

# %%
df.Primary_Genre.unique()
# Out:
# array(['Education', 'Book', 'Reference', 'News', 'Lifestyle',
#        'Health & Fitness', 'Games', 'Medical', 'Food & Drink', 'Sports',
#        'Shopping', 'Entertainment', 'Utilities', 'Stickers',
#        'Productivity', 'Music', 'Photo & Video', 'Travel', 'Business',
#        'Social Networking', 'Magazines & Newspapers', 'Navigation',
#        'Finance', 'Weather', 'Graphics & Design', 'Developer Tools'],
#       dtype=object)

# %%
for i in df.Price.unique():
    print(i)
# Out:
# 0.0
# 2.99
# 1.99
# 0.99
# 4.99
# 9.99
# 5.99
# 6.99
# 16.99
# 19.99
# 39.99
# 59.99
# 8.99
# 7.99
# 18.99
# 3.99
# 24.99
# 14.99
# 28.99
# 21.99
# 13.99
# 10.99
# 11.99
# 129.99
# 22.99
# 139.99
# 25.99
# 12.99
# 49.99
# 23.99
# 119.99
# 79.99
# 17.99
# 499.99
# 249.99
# 199.99
# 229.99
# 34.99
# 20.99
# 99.99
# 33.99
# 54.99
# 45.99
# 44.99
# 29.99
# 69.99
# 27.99
# 84.99
# 64.99
# 15.99
# 26.99
# 35.99
# 40.99
# 174.99
# 149.99
# 94.99
# 74.99
# 349.99
# 48.99
# 109.99
# 38.99
# 31.99
# 36.99
# 89.99
# 169.99
# 124.99
# nan
# 399.99
# 219.99
# 43.99
# 699.99
# 42.99
# 37.99
# 299.99
# 449.99
# 159.99
# 41.99
# 32.99
# 30.99
# 799.99
# 999.99
# 47.99
# 179.99
# 209.99
# 239.99
# 599.99
# 46.99
# 899.99

# %%
import seaborn as sns

# %%
sns.boxplot(x=df.Price)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
app_data_price_hist = df['Price']
app_data_price_hist.plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
app_data_rating_hist = df['Average_User_Rating']
app_data_rating_hist.plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
free_games = df[(df['Primary_Genre'] == 'Games') & (df['Price'] == 0)]
free_games.head(20)
# Out:
#                                               App_Name Primary_Genre  \
# 21                       AAA³ Little Ponies & Unicorns         Games
# 65   Abandoned - Island of Ghosts Monsters and Sold...         Games
# 74   ABC 100 First Words For Children To Listen, Le...         Games
# 109                                  Baby ABC Training         Games
# 115                            Baby Fatts: Magic Match         Games
# 118                    Baby Games App (by HAPPYTOUCH®)         Games
# 134  ABC car games for children: Train your word sp...         Games
# 135  ABC Children’s First Words – Learn the English...         Games
# 136  ABC Children’s First Words – Learn the English...         Games
# 137  ABC Children’s First Words – Learn the English...         Games
# 138  ABC Children’s First Words – Learn the English...         Games
# 139  ABC Christmas games for children to train your...         Games
# 188                     Factions: Raids of the Divided         Games
# ...
